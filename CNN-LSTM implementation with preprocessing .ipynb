# %%
## Importing the necessary packages


import numpy as np
import pandas as pd
import scipy.stats as scs
import re
from numpy import genfromtxt
import keras
from keras.models import Sequential
from keras.layers import Dense, Dropout, Activation, Flatten
from keras.layers import Conv1D, Conv2D,LSTM, BatchNormalization, MaxPooling1D, MaxPooling2D,Reshape
from keras.utils import np_utils
from sklearn.model_selection import train_test_split
from keras.utils import to_categorical
from scipy import signal
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# ~/opt/anaconda3/lib/python3.7/site-packages/keras/__init__.py in <module>
#       2 try:
# ----> 3     from tensorflow.keras.layers.experimental.preprocessing import RandomRotation
#       4 except ImportError:
#
# ModuleNotFoundError: No module named 'tensorflow.keras.layers.experimental.preprocessing'
#
# During handling of the above exception, another exception occurred:
#
# ImportError                               Traceback (most recent call last)
# <ipython-input-2-b62b964a7603> in <module>
#       7 import re
#       8 from numpy import genfromtxt
# ----> 9 import keras
#      10 from keras.models import Sequential
#      11 from keras.layers import Dense, Dropout, Activation, Flatten
#
# ~/opt/anaconda3/lib/python3.7/site-packages/keras/__init__.py in <module>
#       4 except ImportError:
#       5     raise ImportError(
# ----> 6         'Keras requires TensorFlow 2.2 or higher. '
#       7         'Install TensorFlow via `pip install tensorflow`')
#       8
#
# ImportError: Keras requires TensorFlow 2.2 or higher. Install TensorFlow via `pip install tensorflow`

# %% [markdown]
# ## Loading the dataset

# %%
## Loading the dataset

## Loading the numpy arrays

X_test = np.load("X_test.npy")
y_test = np.load("y_test.npy")
person_train_valid = np.load("person_train_valid.npy")
X_train_valid = np.load("X_train_valid.npy")
y_train_valid = np.load("y_train_valid.npy")
person_test = np.load("person_test.npy")

## Adjusting the labels so that 

# Cue onset left - 0
# Cue onset right - 1
# Cue onset foot - 2
# Cue onset tongue - 3

y_train_valid -= 769
y_test -= 769


print ('Training/Valid data shape: {}'.format(X_train_valid.shape))
print ('Test data shape: {}'.format(X_test.shape))
print ('Training/Valid target shape: {}'.format(y_train_valid.shape))
print ('Test target shape: {}'.format(y_test.shape))
print ('Person train/valid shape: {}'.format(person_train_valid.shape))
print ('Person test shape: {}'.format(person_test.shape))
# Out:
# Training/Valid data shape: (2115, 22, 1000)
# Test data shape: (443, 22, 1000)
# Training/Valid target shape: (2115,)
# Test target shape: (443,)
# Person train/valid shape: (2115, 1)
# Person test shape: (443, 1)

# %% [markdown]
# ## Preprocessing the dataset and preparing the training, validation, and test datasets

# %%
def data_prep(X,y,sub_sample,average,noise):
    
    total_X = None
    total_y = None
    
    # Trimming the data
    X = X[:,:,0:500]
    
    # Maxpooling the data
    X_max = np.max(X.reshape(X.shape[0], X.shape[1], -1, sub_sample), axis=3)
    
    total_X = X_max
    total_y = y
    
    # Averaging + noise
    X_average = np.mean(X.reshape(X.shape[0], X.shape[1], -1, average),axis=3)
    X_average = X_average + np.random.normal(0.0, 0.5, X_average.shape)
    
    total_X = np.vstack((total_X, X_average))
    total_y = np.hstack((total_y, y))
    
    # Subsampling
    
    for i in range(sub_sample):
        
        X_subsample = X[:, :, i::sub_sample] + \
                            (np.random.normal(0.0, 0.5, X[:, :,i::sub_sample].shape) if noise else 0.0)
            
        total_X = np.vstack((total_X, X_subsample))
        total_y = np.hstack((total_y, y))
        
        
    return total_X,total_y


X_train_valid_prep,y_train_valid_prep = data_prep(X_train_valid,y_train_valid,2,2,True)
X_test_prep,y_test_prep = data_prep(X_test,y_test,2,2,True)

print(X_train_valid_prep.shape)
print(y_train_valid_prep.shape)
print(X_test_prep.shape)
print(y_test_prep.shape)
# Out:
# (8460, 22, 250)
# (8460,)
# (1772, 22, 250)
# (1772,)

# %%
# random splitting
ind_valid = np.random.choice(8460, 1500, replace=False)
ind_train = np.array(list(set(range(8460)).difference(set(ind_valid))))
(x_train, x_valid) = X_train_valid_prep[ind_train], X_train_valid_prep[ind_valid] 
(y_train, y_valid) = y_train_valid_prep[ind_train], y_train_valid_prep[ind_valid]

y_train = to_categorical(y_train, 4)
y_valid = to_categorical(y_valid, 4)

x_train = x_train.reshape(x_train.shape[0], x_train.shape[1], x_train.shape[2], 1)
x_valid = x_valid.reshape(x_valid.shape[0], x_valid.shape[1], x_train.shape[2], 1)

x_train = np.swapaxes(x_train, 1,3)
x_train = np.swapaxes(x_train, 1,2)
x_valid = np.swapaxes(x_valid, 1,3)
x_valid = np.swapaxes(x_valid, 1,2)

x_test = X_test_ica.reshape(X_test_prep.shape[0], X_test_prep.shape[1], X_test_prep.shape[2], 1)
x_test = np.swapaxes(x_test, 1,3)
x_test = np.swapaxes(x_test, 1,2)
y_test = to_categorical(y_test_prep, 4)

print (x_train.shape)
print (y_train.shape)
print (x_test.shape)
print (y_test.shape)
print (x_valid.shape)
print (y_valid.shape)
# Out:
# (6960, 250, 1, 22)
# (6960, 4)
# (1772, 250, 1, 22)
# (1772, 4)
# (1500, 250, 1, 22)
# (1500, 4)

# %% [markdown]
# ## Building a basic CNN model and then training, validating and testing it.

# %%
# Model parameters
dropout = 0.5
learning_rate = 1e-3
epochs = 50

#Building the model

cnn_model = Sequential()

# First block of conv.
cnn_model.add(Conv2D(filters=25, kernel_size=(10,1), padding='same', activation='elu', input_shape=(250,1,22)))
cnn_model.add(MaxPooling2D(pool_size=(3,1), padding='same'))
cnn_model.add(BatchNormalization())
cnn_model.add(Dropout(dropout))

# Second block of conv.
cnn_model.add(Conv2D(filters=50, kernel_size=(10,1), padding='same', activation='elu'))
cnn_model.add(MaxPooling2D(pool_size=(3,1), padding='same'))
cnn_model.add(BatchNormalization())
cnn_model.add(Dropout(dropout))

# Third block of conv.
cnn_model.add(Conv2D(filters=100, kernel_size=(10,1), padding='same', activation='elu'))
cnn_model.add(MaxPooling2D(pool_size=(3,1), padding='same'))
cnn_model.add(BatchNormalization())
cnn_model.add(Dropout(dropout))

# Fourth block of conv.
cnn_model.add(Conv2D(filters=200, kernel_size=(10,1), padding='same', activation='elu'))
cnn_model.add(MaxPooling2D(pool_size=(3,1), padding='same'))
cnn_model.add(BatchNormalization())
cnn_model.add(Dropout(dropout))

# FC layer
cnn_model.add(Flatten())
cnn_model.add(Dense(4, activation='softmax'))

# Defining the optimizer
optimizer = keras.optimizers.Adam(lr=learning_rate)

# Compiling the model
cnn_model.compile(loss='categorical_crossentropy',
                 optimizer=optimizer,
                 metrics=['accuracy'])

# Printing the model summary
cnn_model.summary()

# Training and validating the model

cnn_results = cnn_model.fit(x_train,
             y_train,
             batch_size=64,
             epochs=epochs,
             validation_data=(x_valid, y_valid), verbose=True)
# Out:
# Model: "sequential_11"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# conv2d_42 (Conv2D)           (None, 250, 1, 25)        5525
# _________________________________________________________________
# max_pooling2d_42 (MaxPooling (None, 84, 1, 25)         0
# _________________________________________________________________
# batch_normalization_42 (Batc (None, 84, 1, 25)         100
# _________________________________________________________________
# dropout_42 (Dropout)         (None, 84, 1, 25)         0
# _________________________________________________________________
# conv2d_43 (Conv2D)           (None, 84, 1, 50)         12550
# _________________________________________________________________
# max_pooling2d_43 (MaxPooling (None, 28, 1, 50)         0
# _________________________________________________________________
# batch_normalization_43 (Batc (None, 28, 1, 50)         200
# _________________________________________________________________
# dropout_43 (Dropout)         (None, 28, 1, 50)         0
# _________________________________________________________________
# conv2d_44 (Conv2D)           (None, 28, 1, 100)        50100
# _________________________________________________________________
# max_pooling2d_44 (MaxPooling (None, 10, 1, 100)        0
# _________________________________________________________________
# batch_normalization_44 (Batc (None, 10, 1, 100)        400
# _________________________________________________________________
# dropout_44 (Dropout)         (None, 10, 1, 100)        0
# _________________________________________________________________
# conv2d_45 (Conv2D)           (None, 10, 1, 200)        200200
# _________________________________________________________________
# max_pooling2d_45 (MaxPooling (None, 4, 1, 200)         0
# _________________________________________________________________
# batch_normalization_45 (Batc (None, 4, 1, 200)         800
# _________________________________________________________________
# dropout_45 (Dropout)         (None, 4, 1, 200)         0
# _________________________________________________________________
# flatten_11 (Flatten)         (None, 800)               0
# _________________________________________________________________
# dense_13 (Dense)             (None, 4)                 3204
# =================================================================
# Total params: 273,079
# Trainable params: 272,329
# Non-trainable params: 750
# _________________________________________________________________
# Epoch 1/50
# 109/109 [==============================] - 6s 48ms/step - loss: 2.1935 - accuracy: 0.3014 - val_loss: 1.4422 - val_accuracy: 0.4220
# Epoch 2/50
# 109/109 [==============================] - 5s 44ms/step - loss: 1.6296 - accuracy: 0.3692 - val_loss: 1.1710 - val_accuracy: 0.5013
# Epoch 3/50
# 109/109 [==============================] - 5s 44ms/step - loss: 1.3462 - accuracy: 0.4358 - val_loss: 1.1960 - val_accuracy: 0.4560
# Epoch 4/50
# 109/109 [==============================] - 5s 44ms/step - loss: 1.2135 - accuracy: 0.4989 - val_loss: 1.0474 - val_accuracy: 0.5907
# Epoch 5/50
# 109/109 [==============================] - 5s 46ms/step - loss: 1.1352 - accuracy: 0.5233 - val_loss: 0.9569 - val_accuracy: 0.6147
# Epoch 6/50
# 109/109 [==============================] - 5s 45ms/step - loss: 1.0454 - accuracy: 0.5536 - val_loss: 0.8982 - val_accuracy: 0.6360
# Epoch 7/50
# 109/109 [==============================] - 5s 47ms/step - loss: 0.9982 - accuracy: 0.5844 - val_loss: 0.8515 - val_accuracy: 0.6807
# Epoch 8/50
# 109/109 [==============================] - 5s 44ms/step - loss: 0.9713 - accuracy: 0.6049 - val_loss: 0.7852 - val_accuracy: 0.7040
# Epoch 9/50
# 109/109 [==============================] - 5s 45ms/step - loss: 0.9262 - accuracy: 0.6324 - val_loss: 0.7844 - val_accuracy: 0.6900
# Epoch 10/50
# 109/109 [==============================] - 5s 45ms/step - loss: 0.9010 - accuracy: 0.6349 - val_loss: 0.7474 - val_accuracy: 0.7187
# Epoch 11/50
# 109/109 [==============================] - 5s 46ms/step - loss: 0.8629 - accuracy: 0.6555 - val_loss: 0.6801 - val_accuracy: 0.7480
# Epoch 12/50
# 109/109 [==============================] - 5s 49ms/step - loss: 0.8121 - accuracy: 0.6745 - val_loss: 0.7109 - val_accuracy: 0.7173
# Epoch 13/50
# 109/109 [==============================] - 5s 44ms/step - loss: 0.7947 - accuracy: 0.6868 - val_loss: 0.6480 - val_accuracy: 0.7627
# Epoch 14/50
# 109/109 [==============================] - 5s 45ms/step - loss: 0.7728 - accuracy: 0.6909 - val_loss: 0.5935 - val_accuracy: 0.7947
# Epoch 15/50
# 109/109 [==============================] - 5s 47ms/step - loss: 0.7444 - accuracy: 0.7086 - val_loss: 0.5818 - val_accuracy: 0.7900
# Epoch 16/50
# 109/109 [==============================] - 5s 47ms/step - loss: 0.7196 - accuracy: 0.7227 - val_loss: 0.5429 - val_accuracy: 0.8140
# Epoch 17/50
# 109/109 [==============================] - 5s 45ms/step - loss: 0.7188 - accuracy: 0.7137 - val_loss: 0.5196 - val_accuracy: 0.8107
# Epoch 18/50
# 109/109 [==============================] - 5s 45ms/step - loss: 0.6979 - accuracy: 0.7229 - val_loss: 0.4923 - val_accuracy: 0.8193
# Epoch 19/50
# 109/109 [==============================] - 5s 45ms/step - loss: 0.6694 - accuracy: 0.7393 - val_loss: 0.5360 - val_accuracy: 0.7860
# Epoch 20/50
# 109/109 [==============================] - 5s 44ms/step - loss: 0.6509 - accuracy: 0.7546 - val_loss: 0.4618 - val_accuracy: 0.8347
# Epoch 21/50
# 109/109 [==============================] - 5s 45ms/step - loss: 0.6275 - accuracy: 0.7518 - val_loss: 0.4510 - val_accuracy: 0.8400
# Epoch 22/50
# 109/109 [==============================] - 5s 47ms/step - loss: 0.6200 - accuracy: 0.7637 - val_loss: 0.4271 - val_accuracy: 0.8473
# Epoch 23/50
# 109/109 [==============================] - 6s 55ms/step - loss: 0.6052 - accuracy: 0.7540 - val_loss: 0.4234 - val_accuracy: 0.8413
# Epoch 24/50
# 109/109 [==============================] - 5s 44ms/step - loss: 0.6089 - accuracy: 0.7622 - val_loss: 0.4119 - val_accuracy: 0.8520
# Epoch 25/50
# 109/109 [==============================] - 5s 44ms/step - loss: 0.5779 - accuracy: 0.7786 - val_loss: 0.3458 - val_accuracy: 0.8900
# Epoch 26/50
# 109/109 [==============================] - 5s 44ms/step - loss: 0.5510 - accuracy: 0.7895 - val_loss: 0.3592 - val_accuracy: 0.8760
# Epoch 27/50
# 109/109 [==============================] - 5s 44ms/step - loss: 0.5403 - accuracy: 0.7875 - val_loss: 0.3285 - val_accuracy: 0.8973
# Epoch 28/50
# 109/109 [==============================] - 5s 44ms/step - loss: 0.5466 - accuracy: 0.7853 - val_loss: 0.3556 - val_accuracy: 0.8773
# Epoch 29/50
# 109/109 [==============================] - 5s 44ms/step - loss: 0.5253 - accuracy: 0.7940 - val_loss: 0.3108 - val_accuracy: 0.8887
# Epoch 30/50
# 109/109 [==============================] - 5s 44ms/step - loss: 0.5097 - accuracy: 0.8042 - val_loss: 0.2788 - val_accuracy: 0.9020
# Epoch 31/50
# 109/109 [==============================] - 5s 44ms/step - loss: 0.5150 - accuracy: 0.8030 - val_loss: 0.2693 - val_accuracy: 0.9100
# Epoch 32/50
# 109/109 [==============================] - 5s 46ms/step - loss: 0.4870 - accuracy: 0.8092 - val_loss: 0.2624 - val_accuracy: 0.9180
# Epoch 33/50
# 109/109 [==============================] - 5s 44ms/step - loss: 0.5067 - accuracy: 0.8063 - val_loss: 0.2610 - val_accuracy: 0.9133
# Epoch 34/50
# 109/109 [==============================] - 5s 45ms/step - loss: 0.4673 - accuracy: 0.8237 - val_loss: 0.2746 - val_accuracy: 0.8980
# Epoch 35/50
# 109/109 [==============================] - 5s 44ms/step - loss: 0.4772 - accuracy: 0.8183 - val_loss: 0.2138 - val_accuracy: 0.9393
# Epoch 36/50
# 109/109 [==============================] - 5s 44ms/step - loss: 0.4489 - accuracy: 0.8259 - val_loss: 0.2296 - val_accuracy: 0.9320
# Epoch 37/50
# 109/109 [==============================] - 5s 44ms/step - loss: 0.4611 - accuracy: 0.8263 - val_loss: 0.2032 - val_accuracy: 0.9460
# Epoch 38/50
# 109/109 [==============================] - 5s 44ms/step - loss: 0.4478 - accuracy: 0.8304 - val_loss: 0.1830 - val_accuracy: 0.9573
# Epoch 39/50
# 109/109 [==============================] - 5s 43ms/step - loss: 0.4359 - accuracy: 0.8279 - val_loss: 0.1890 - val_accuracy: 0.9460
# Epoch 40/50
# 109/109 [==============================] - 5s 43ms/step - loss: 0.4145 - accuracy: 0.8427 - val_loss: 0.1799 - val_accuracy: 0.9527
# Epoch 41/50
# 109/109 [==============================] - 5s 43ms/step - loss: 0.3927 - accuracy: 0.8529 - val_loss: 0.1790 - val_accuracy: 0.9420
# Epoch 42/50
# 109/109 [==============================] - 5s 43ms/step - loss: 0.3898 - accuracy: 0.8556 - val_loss: 0.1485 - val_accuracy: 0.9640
# Epoch 43/50
# 109/109 [==============================] - 5s 43ms/step - loss: 0.3993 - accuracy: 0.8513 - val_loss: 0.1406 - val_accuracy: 0.9693
# Epoch 44/50
# 109/109 [==============================] - 5s 43ms/step - loss: 0.3980 - accuracy: 0.8455 - val_loss: 0.1462 - val_accuracy: 0.9553
# Epoch 45/50
# 109/109 [==============================] - 5s 43ms/step - loss: 0.3887 - accuracy: 0.8546 - val_loss: 0.1443 - val_accuracy: 0.9653
# Epoch 46/50
# 109/109 [==============================] - 5s 43ms/step - loss: 0.3850 - accuracy: 0.8530 - val_loss: 0.1304 - val_accuracy: 0.9640
# Epoch 47/50
# 109/109 [==============================] - 5s 43ms/step - loss: 0.3948 - accuracy: 0.8545 - val_loss: 0.1292 - val_accuracy: 0.9627
# Epoch 48/50
# 109/109 [==============================] - 5s 43ms/step - loss: 0.3540 - accuracy: 0.8707 - val_loss: 0.1410 - val_accuracy: 0.9640
# Epoch 49/50
# 109/109 [==============================] - 5s 43ms/step - loss: 0.3564 - accuracy: 0.8607 - val_loss: 0.1271 - val_accuracy: 0.9673
# Epoch 50/50
# 109/109 [==============================] - 5s 43ms/step - loss: 0.3497 - accuracy: 0.8692 - val_loss: 0.1001 - val_accuracy: 0.9780

# %%
import matplotlib.pyplot as plt

# list all data in history
#print(history.history.keys())

# summarize history for accuracy
plt.plot(cnn_results.history['accuracy'])
plt.plot(cnn_results.history['val_accuracy'])
plt.title('CNN model accuracy with data preprocessing')
plt.ylabel('accuracy')
plt.xlabel('epoch')
plt.legend(['train', 'val'], loc='upper left')
plt.show()

# summarize history for loss
plt.plot(cnn_results.history['loss'],'o')
plt.plot(cnn_results.history['val_loss'],'o')
plt.title('CNN model loss with data preprocessing')
plt.ylabel('loss')
plt.xlabel('epoch')
plt.legend(['train', 'val'], loc='upper left')
plt.show()

# %%
## Testing the CNN model

score = cnn_model.evaluate(x_test, y_test, verbose=0)
print('Test accuracy of the CNN model:',score[1])
# Out:
# Test accuracy of the CNN model: 0.7178329825401306

# %% [markdown]
# ## Building a basic CNN-LSTM model and then training, validating and testing it.

# %%
# Model parameters
dropout = 0.5
learning_rate = 1e-3
epochs = 100

#Building the model

cnn_lstm_model = Sequential()

# First block of conv.
cnn_lstm_model.add(Conv2D(filters=25, kernel_size=(10,1), padding='same', activation='elu', input_shape=(250,1,22)))
cnn_lstm_model.add(MaxPooling2D(pool_size=(3,1), padding='same'))
cnn_lstm_model.add(BatchNormalization())
cnn_lstm_model.add(Dropout(dropout))

# Second block of conv.
cnn_lstm_model.add(Conv2D(filters=50, kernel_size=(10,1), padding='same', activation='elu'))
cnn_lstm_model.add(MaxPooling2D(pool_size=(3,1), padding='same'))
cnn_lstm_model.add(BatchNormalization())
cnn_lstm_model.add(Dropout(dropout))

# Third block of conv.
cnn_lstm_model.add(Conv2D(filters=100, kernel_size=(10,1), padding='same', activation='elu'))
cnn_lstm_model.add(MaxPooling2D(pool_size=(3,1), padding='same'))
cnn_lstm_model.add(BatchNormalization())
cnn_lstm_model.add(Dropout(dropout))

# FC+LSTM layer
cnn_lstm_model.add(Flatten())
cnn_lstm_model.add(Dense((50)))
cnn_lstm_model.add(Reshape((50,1)))
cnn_lstm_model.add(LSTM(10, dropout=0.5, recurrent_dropout=0.5, input_shape=(50,1), return_sequences=False))

# FC layer
cnn_lstm_model.add(Dense(4, activation='softmax'))

# Defining the optimizer
optimizer = keras.optimizers.Adam(lr=learning_rate)

# Compiling the model
cnn_lstm_model.compile(loss='categorical_crossentropy',
                 optimizer=optimizer,
                 metrics=['accuracy'])

# Printing the model summary
cnn_lstm_model.summary()

# Training and validating the model

cnn_lstm_results = cnn_lstm_model.fit(x_train,
             y_train,
             batch_size=64,
             epochs=epochs,
             validation_data=(x_valid, y_valid), verbose=True)
# Out:
# Model: "sequential_13"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# conv2d_49 (Conv2D)           (None, 250, 1, 25)        5525
# _________________________________________________________________
# max_pooling2d_49 (MaxPooling (None, 84, 1, 25)         0
# _________________________________________________________________
# batch_normalization_49 (Batc (None, 84, 1, 25)         100
# _________________________________________________________________
# dropout_49 (Dropout)         (None, 84, 1, 25)         0
# _________________________________________________________________
# conv2d_50 (Conv2D)           (None, 84, 1, 50)         12550
# _________________________________________________________________
# max_pooling2d_50 (MaxPooling (None, 28, 1, 50)         0
# _________________________________________________________________
# batch_normalization_50 (Batc (None, 28, 1, 50)         200
# _________________________________________________________________
# dropout_50 (Dropout)         (None, 28, 1, 50)         0
# _________________________________________________________________
# conv2d_51 (Conv2D)           (None, 28, 1, 100)        50100
# _________________________________________________________________
# max_pooling2d_51 (MaxPooling (None, 10, 1, 100)        0
# _________________________________________________________________
# batch_normalization_51 (Batc (None, 10, 1, 100)        400
# _________________________________________________________________
# dropout_51 (Dropout)         (None, 10, 1, 100)        0
# _________________________________________________________________
# flatten_13 (Flatten)         (None, 1000)              0
# _________________________________________________________________
# dense_16 (Dense)             (None, 50)                50050
# _________________________________________________________________
# reshape_3 (Reshape)          (None, 50, 1)             0
# _________________________________________________________________
# lstm_3 (LSTM)                (None, 10)                480
# _________________________________________________________________
# dense_17 (Dense)             (None, 4)                 44
# =================================================================
# Total params: 119,449
# Trainable params: 119,099
# Non-trainable params: 350
# _________________________________________________________________
# Epoch 1/100
# 109/109 [==============================] - 11s 79ms/step - loss: 1.3868 - accuracy: 0.2720 - val_loss: 1.3746 - val_accuracy: 0.3060
# Epoch 2/100
# 109/109 [==============================] - 8s 77ms/step - loss: 1.3578 - accuracy: 0.3395 - val_loss: 1.2965 - val_accuracy: 0.3787
# Epoch 3/100
# 109/109 [==============================] - 8s 77ms/step - loss: 1.3043 - accuracy: 0.3904 - val_loss: 1.2096 - val_accuracy: 0.4493
# Epoch 4/100
# 109/109 [==============================] - 8s 76ms/step - loss: 1.2114 - accuracy: 0.4628 - val_loss: 1.2025 - val_accuracy: 0.4300
# Epoch 5/100
# 109/109 [==============================] - 8s 75ms/step - loss: 1.1768 - accuracy: 0.4832 - val_loss: 1.1199 - val_accuracy: 0.4827
# Epoch 6/100
# 109/109 [==============================] - 8s 76ms/step - loss: 1.1364 - accuracy: 0.4926 - val_loss: 1.1070 - val_accuracy: 0.5153
# Epoch 7/100
# 109/109 [==============================] - 8s 76ms/step - loss: 1.1328 - accuracy: 0.4904 - val_loss: 1.0562 - val_accuracy: 0.5313
# Epoch 8/100
# 109/109 [==============================] - 8s 77ms/step - loss: 1.0904 - accuracy: 0.5135 - val_loss: 1.0970 - val_accuracy: 0.5087
# Epoch 9/100
# 109/109 [==============================] - 8s 76ms/step - loss: 1.0726 - accuracy: 0.5382 - val_loss: 1.0466 - val_accuracy: 0.5320
# Epoch 10/100
# 109/109 [==============================] - 8s 73ms/step - loss: 1.0462 - accuracy: 0.5415 - val_loss: 1.0286 - val_accuracy: 0.5440
# Epoch 11/100
# 109/109 [==============================] - 8s 73ms/step - loss: 1.0218 - accuracy: 0.5500 - val_loss: 1.0097 - val_accuracy: 0.5540
# Epoch 12/100
# 109/109 [==============================] - 8s 74ms/step - loss: 1.0088 - accuracy: 0.5501 - val_loss: 0.9599 - val_accuracy: 0.5780
# Epoch 13/100
# 109/109 [==============================] - 8s 73ms/step - loss: 0.9649 - accuracy: 0.5830 - val_loss: 0.9091 - val_accuracy: 0.6047
# Epoch 14/100
# 109/109 [==============================] - 8s 74ms/step - loss: 0.9590 - accuracy: 0.5881 - val_loss: 0.8988 - val_accuracy: 0.6087
# Epoch 15/100
# 109/109 [==============================] - 8s 74ms/step - loss: 0.9587 - accuracy: 0.5756 - val_loss: 0.8841 - val_accuracy: 0.6153
# Epoch 16/100
# 109/109 [==============================] - 8s 74ms/step - loss: 0.9257 - accuracy: 0.6009 - val_loss: 0.9375 - val_accuracy: 0.5827
# Epoch 17/100
# 109/109 [==============================] - 8s 74ms/step - loss: 0.9258 - accuracy: 0.5954 - val_loss: 0.8680 - val_accuracy: 0.6113
# Epoch 18/100
# 109/109 [==============================] - 8s 74ms/step - loss: 0.8951 - accuracy: 0.6123 - val_loss: 0.8282 - val_accuracy: 0.6340
# Epoch 19/100
# 109/109 [==============================] - 8s 73ms/step - loss: 0.8864 - accuracy: 0.6140 - val_loss: 0.7964 - val_accuracy: 0.6633
# Epoch 20/100
# 109/109 [==============================] - 8s 74ms/step - loss: 0.9075 - accuracy: 0.6108 - val_loss: 0.9092 - val_accuracy: 0.5940
# Epoch 21/100
# 109/109 [==============================] - 8s 74ms/step - loss: 0.8880 - accuracy: 0.6141 - val_loss: 0.8139 - val_accuracy: 0.6287
# Epoch 22/100
# 109/109 [==============================] - 8s 72ms/step - loss: 0.8680 - accuracy: 0.6175 - val_loss: 0.7828 - val_accuracy: 0.6520
# Epoch 23/100
# 109/109 [==============================] - 8s 72ms/step - loss: 0.8412 - accuracy: 0.6360 - val_loss: 0.7902 - val_accuracy: 0.6487
# Epoch 24/100
# 109/109 [==============================] - 8s 72ms/step - loss: 0.8308 - accuracy: 0.6369 - val_loss: 0.7349 - val_accuracy: 0.6773
# Epoch 25/100
# 109/109 [==============================] - 8s 72ms/step - loss: 0.8248 - accuracy: 0.6539 - val_loss: 0.7589 - val_accuracy: 0.6727
# Epoch 26/100
# 109/109 [==============================] - 8s 72ms/step - loss: 0.8272 - accuracy: 0.6351 - val_loss: 0.7823 - val_accuracy: 0.6447
# Epoch 27/100
# 109/109 [==============================] - 8s 72ms/step - loss: 0.8120 - accuracy: 0.6434 - val_loss: 0.7414 - val_accuracy: 0.6727
# Epoch 28/100
# 109/109 [==============================] - 8s 73ms/step - loss: 0.8098 - accuracy: 0.6560 - val_loss: 0.6799 - val_accuracy: 0.7133
# Epoch 29/100
# 109/109 [==============================] - 8s 72ms/step - loss: 0.7921 - accuracy: 0.6580 - val_loss: 0.7212 - val_accuracy: 0.6753
# Epoch 30/100
# 109/109 [==============================] - 8s 72ms/step - loss: 0.8006 - accuracy: 0.6624 - val_loss: 0.7355 - val_accuracy: 0.6607
# Epoch 31/100
# 109/109 [==============================] - 8s 72ms/step - loss: 0.7905 - accuracy: 0.6638 - val_loss: 0.6662 - val_accuracy: 0.7140
# Epoch 32/100
# 109/109 [==============================] - 8s 72ms/step - loss: 0.7903 - accuracy: 0.6732 - val_loss: 0.7244 - val_accuracy: 0.6813
# Epoch 33/100
# 109/109 [==============================] - 8s 72ms/step - loss: 0.7650 - accuracy: 0.6845 - val_loss: 0.6190 - val_accuracy: 0.7473
# Epoch 34/100
# 109/109 [==============================] - 8s 72ms/step - loss: 0.7424 - accuracy: 0.6992 - val_loss: 0.6509 - val_accuracy: 0.7553
# Epoch 35/100
# 109/109 [==============================] - 8s 72ms/step - loss: 0.7457 - accuracy: 0.6907 - val_loss: 0.6616 - val_accuracy: 0.7527
# Epoch 36/100
# 109/109 [==============================] - 8s 72ms/step - loss: 0.7396 - accuracy: 0.6921 - val_loss: 0.5790 - val_accuracy: 0.8033
# Epoch 37/100
# 109/109 [==============================] - 8s 72ms/step - loss: 0.7060 - accuracy: 0.7244 - val_loss: 0.5543 - val_accuracy: 0.8000
# Epoch 38/100
# 109/109 [==============================] - 8s 69ms/step - loss: 0.7075 - accuracy: 0.7217 - val_loss: 0.5598 - val_accuracy: 0.8033
# Epoch 39/100
# 109/109 [==============================] - 7s 68ms/step - loss: 0.7017 - accuracy: 0.7230 - val_loss: 0.5165 - val_accuracy: 0.8353
# Epoch 40/100
# 109/109 [==============================] - 7s 68ms/step - loss: 0.6819 - accuracy: 0.7446 - val_loss: 0.5561 - val_accuracy: 0.8100
# Epoch 41/100
# 109/109 [==============================] - 7s 67ms/step - loss: 0.6744 - accuracy: 0.7473 - val_loss: 0.4869 - val_accuracy: 0.8493
# Epoch 42/100
# 109/109 [==============================] - 8s 71ms/step - loss: 0.6573 - accuracy: 0.7528 - val_loss: 0.4470 - val_accuracy: 0.8607
# Epoch 43/100
# 109/109 [==============================] - 8s 71ms/step - loss: 0.6487 - accuracy: 0.7607 - val_loss: 0.4612 - val_accuracy: 0.8567
# Epoch 44/100
# 109/109 [==============================] - 8s 69ms/step - loss: 0.6381 - accuracy: 0.7632 - val_loss: 0.4481 - val_accuracy: 0.8607
# Epoch 45/100
# 109/109 [==============================] - 8s 69ms/step - loss: 0.6146 - accuracy: 0.7784 - val_loss: 0.4183 - val_accuracy: 0.8660
# Epoch 46/100
# 109/109 [==============================] - 8s 70ms/step - loss: 0.6116 - accuracy: 0.7741 - val_loss: 0.4401 - val_accuracy: 0.8687
# Epoch 47/100
# 109/109 [==============================] - 8s 70ms/step - loss: 0.5758 - accuracy: 0.7926 - val_loss: 0.4379 - val_accuracy: 0.8487
# Epoch 48/100
# 109/109 [==============================] - 8s 70ms/step - loss: 0.5774 - accuracy: 0.7877 - val_loss: 0.4113 - val_accuracy: 0.8567
# Epoch 49/100
# 109/109 [==============================] - 8s 69ms/step - loss: 0.5859 - accuracy: 0.7853 - val_loss: 0.3728 - val_accuracy: 0.8847
# Epoch 50/100
# 109/109 [==============================] - 8s 70ms/step - loss: 0.5936 - accuracy: 0.7865 - val_loss: 0.4128 - val_accuracy: 0.8720
# Epoch 51/100
# 109/109 [==============================] - 8s 69ms/step - loss: 0.5920 - accuracy: 0.7864 - val_loss: 0.4045 - val_accuracy: 0.8687
# Epoch 52/100
# 109/109 [==============================] - 8s 70ms/step - loss: 0.5713 - accuracy: 0.7910 - val_loss: 0.3938 - val_accuracy: 0.8747
# Epoch 53/100
# 109/109 [==============================] - 8s 69ms/step - loss: 0.5509 - accuracy: 0.7943 - val_loss: 0.3746 - val_accuracy: 0.8887
# Epoch 54/100
# 109/109 [==============================] - 8s 70ms/step - loss: 0.5490 - accuracy: 0.7946 - val_loss: 0.3568 - val_accuracy: 0.8867
# Epoch 55/100
# 109/109 [==============================] - 8s 69ms/step - loss: 0.5617 - accuracy: 0.7899 - val_loss: 0.3418 - val_accuracy: 0.8987
# Epoch 56/100
# 109/109 [==============================] - 8s 71ms/step - loss: 0.5481 - accuracy: 0.8002 - val_loss: 0.3572 - val_accuracy: 0.8973
# Epoch 57/100
# 109/109 [==============================] - 7s 68ms/step - loss: 0.5351 - accuracy: 0.8027 - val_loss: 0.3095 - val_accuracy: 0.9147
# Epoch 58/100
# 109/109 [==============================] - 8s 70ms/step - loss: 0.5394 - accuracy: 0.8064 - val_loss: 0.3238 - val_accuracy: 0.9000
# Epoch 59/100
# 109/109 [==============================] - 8s 71ms/step - loss: 0.5499 - accuracy: 0.8001 - val_loss: 0.3131 - val_accuracy: 0.9140
# Epoch 60/100
# 109/109 [==============================] - 8s 72ms/step - loss: 0.5398 - accuracy: 0.7989 - val_loss: 0.3309 - val_accuracy: 0.8987
# Epoch 61/100
# 109/109 [==============================] - 8s 71ms/step - loss: 0.5316 - accuracy: 0.8062 - val_loss: 0.2933 - val_accuracy: 0.9153
# Epoch 62/100
# 109/109 [==============================] - 8s 71ms/step - loss: 0.5145 - accuracy: 0.8114 - val_loss: 0.2850 - val_accuracy: 0.9167
# Epoch 63/100
# 109/109 [==============================] - 8s 71ms/step - loss: 0.4930 - accuracy: 0.8228 - val_loss: 0.3076 - val_accuracy: 0.9067
# Epoch 64/100
# 109/109 [==============================] - 8s 72ms/step - loss: 0.5381 - accuracy: 0.8064 - val_loss: 0.2818 - val_accuracy: 0.9260
# Epoch 65/100
# 109/109 [==============================] - 8s 71ms/step - loss: 0.4662 - accuracy: 0.8311 - val_loss: 0.3182 - val_accuracy: 0.9033
# Epoch 66/100
# 109/109 [==============================] - 8s 71ms/step - loss: 0.4766 - accuracy: 0.8274 - val_loss: 0.2722 - val_accuracy: 0.9207
# Epoch 67/100
# 109/109 [==============================] - 8s 71ms/step - loss: 0.4737 - accuracy: 0.8296 - val_loss: 0.2607 - val_accuracy: 0.9227
# Epoch 68/100
# 109/109 [==============================] - 8s 71ms/step - loss: 0.4936 - accuracy: 0.8190 - val_loss: 0.2250 - val_accuracy: 0.9413
# Epoch 69/100
# 109/109 [==============================] - 8s 71ms/step - loss: 0.4713 - accuracy: 0.8296 - val_loss: 0.2598 - val_accuracy: 0.9273
# Epoch 70/100
# 109/109 [==============================] - 8s 71ms/step - loss: 0.5002 - accuracy: 0.8170 - val_loss: 0.2330 - val_accuracy: 0.9400
# Epoch 71/100
# 109/109 [==============================] - 8s 71ms/step - loss: 0.4727 - accuracy: 0.8289 - val_loss: 0.2516 - val_accuracy: 0.9307
# Epoch 72/100
# 109/109 [==============================] - 8s 71ms/step - loss: 0.4720 - accuracy: 0.8295 - val_loss: 0.2401 - val_accuracy: 0.9347
# Epoch 73/100
# 109/109 [==============================] - 8s 71ms/step - loss: 0.4534 - accuracy: 0.8282 - val_loss: 0.2408 - val_accuracy: 0.9320
# Epoch 74/100
# 109/109 [==============================] - 8s 71ms/step - loss: 0.4580 - accuracy: 0.8332 - val_loss: 0.2208 - val_accuracy: 0.9400
# Epoch 75/100
# 109/109 [==============================] - 8s 72ms/step - loss: 0.4529 - accuracy: 0.8350 - val_loss: 0.1941 - val_accuracy: 0.9487
# Epoch 76/100
# 109/109 [==============================] - 8s 71ms/step - loss: 0.4373 - accuracy: 0.8370 - val_loss: 0.2023 - val_accuracy: 0.9500
# Epoch 77/100
# 109/109 [==============================] - 8s 71ms/step - loss: 0.4546 - accuracy: 0.8327 - val_loss: 0.1983 - val_accuracy: 0.9420
# Epoch 78/100
# 109/109 [==============================] - 8s 69ms/step - loss: 0.4447 - accuracy: 0.8318 - val_loss: 0.1981 - val_accuracy: 0.9440
# Epoch 79/100
# 109/109 [==============================] - 8s 71ms/step - loss: 0.4324 - accuracy: 0.8426 - val_loss: 0.2171 - val_accuracy: 0.9327
# Epoch 80/100
# 109/109 [==============================] - 8s 71ms/step - loss: 0.4373 - accuracy: 0.8403 - val_loss: 0.2078 - val_accuracy: 0.9433
# Epoch 81/100
# 109/109 [==============================] - 8s 71ms/step - loss: 0.4745 - accuracy: 0.8222 - val_loss: 0.2164 - val_accuracy: 0.9407
# Epoch 82/100
# 109/109 [==============================] - 8s 71ms/step - loss: 0.4369 - accuracy: 0.8416 - val_loss: 0.1827 - val_accuracy: 0.9513
# Epoch 83/100
# 109/109 [==============================] - 8s 70ms/step - loss: 0.4343 - accuracy: 0.8426 - val_loss: 0.2305 - val_accuracy: 0.9260
# Epoch 84/100
# 109/109 [==============================] - 7s 68ms/step - loss: 0.4398 - accuracy: 0.8403 - val_loss: 0.1898 - val_accuracy: 0.9520
# Epoch 85/100
# 109/109 [==============================] - 7s 68ms/step - loss: 0.4172 - accuracy: 0.8506 - val_loss: 0.2223 - val_accuracy: 0.9407
# Epoch 86/100
# 109/109 [==============================] - 7s 68ms/step - loss: 0.4238 - accuracy: 0.8439 - val_loss: 0.1733 - val_accuracy: 0.9573
# Epoch 87/100
# 109/109 [==============================] - 7s 68ms/step - loss: 0.4002 - accuracy: 0.8494 - val_loss: 0.1928 - val_accuracy: 0.9493
# Epoch 88/100
# 109/109 [==============================] - 7s 67ms/step - loss: 0.4027 - accuracy: 0.8576 - val_loss: 0.1735 - val_accuracy: 0.9533
# Epoch 89/100
# 109/109 [==============================] - 7s 68ms/step - loss: 0.4155 - accuracy: 0.8480 - val_loss: 0.1644 - val_accuracy: 0.9547
# Epoch 90/100
# 109/109 [==============================] - 7s 68ms/step - loss: 0.4103 - accuracy: 0.8502 - val_loss: 0.1951 - val_accuracy: 0.9507
# Epoch 91/100
# 109/109 [==============================] - 8s 69ms/step - loss: 0.4112 - accuracy: 0.8517 - val_loss: 0.1618 - val_accuracy: 0.9587
# Epoch 92/100
# 109/109 [==============================] - 8s 71ms/step - loss: 0.4146 - accuracy: 0.8451 - val_loss: 0.1563 - val_accuracy: 0.9560
# Epoch 93/100
# 109/109 [==============================] - 8s 71ms/step - loss: 0.4310 - accuracy: 0.8418 - val_loss: 0.1495 - val_accuracy: 0.9600
# Epoch 94/100
# 109/109 [==============================] - 8s 71ms/step - loss: 0.3922 - accuracy: 0.8594 - val_loss: 0.1380 - val_accuracy: 0.9627
# Epoch 95/100
# 109/109 [==============================] - 8s 71ms/step - loss: 0.3983 - accuracy: 0.8541 - val_loss: 0.1693 - val_accuracy: 0.9540
# Epoch 96/100
# 109/109 [==============================] - 8s 72ms/step - loss: 0.4051 - accuracy: 0.8554 - val_loss: 0.1755 - val_accuracy: 0.9547
# Epoch 97/100
# 109/109 [==============================] - 8s 71ms/step - loss: 0.4159 - accuracy: 0.8462 - val_loss: 0.1512 - val_accuracy: 0.9580
# Epoch 98/100
# 109/109 [==============================] - 8s 71ms/step - loss: 0.4020 - accuracy: 0.8560 - val_loss: 0.1379 - val_accuracy: 0.9620
# Epoch 99/100
# 109/109 [==============================] - 8s 71ms/step - loss: 0.4091 - accuracy: 0.8497 - val_loss: 0.1452 - val_accuracy: 0.9587
# Epoch 100/100
# 109/109 [==============================] - 8s 72ms/step - loss: 0.3904 - accuracy: 0.8619 - val_loss: 0.1602 - val_accuracy: 0.9547

# %%
import matplotlib.pyplot as plt

# list all data in history
#print(history.history.keys())

# summarize history for accuracy
plt.plot(cnn_lstm_results.history['accuracy'])
plt.plot(cnn_lstm_results.history['val_accuracy'])
plt.title('CNN-LSTM model accuracy with data preprocessing')
plt.ylabel('accuracy')
plt.xlabel('epoch')
plt.legend(['train', 'val'], loc='upper left')
plt.show()

# summarize history for loss
plt.plot(cnn_lstm_results.history['loss'],'o')
plt.plot(cnn_lstm_results.history['val_loss'],'o')
plt.title('CNN-LSTM model loss with data preprocessing')
plt.ylabel('loss')
plt.xlabel('epoch')
plt.legend(['train', 'val'], loc='upper left')
plt.show()

# %%
## Testing the CNN-LSTM model

score = cnn_lstm_model.evaluate(x_test, y_test, verbose=0)
print('Test accuracy of the CNN-LSTM model:',score[1])
# Out:
# Test accuracy of the CNN-LSTM model: 0.70033860206604
